# %% [markdown]
# ## Transcript Comparison
# Comparison of multiple Transcripts (Whisper & FHNW Model) to determine DIT and DAT material.

# %% [markdown]
# ### Imports

# %%
import pandas as pd
from pathlib import Path
from functools import reduce

# %% [markdown]
# ### Paths

# %%
SUBSET_DIR = Path.cwd()
ANALYSIS_DIR = SUBSET_DIR / "stt-transcript-analysis"

WHISPER_SMALL = ANALYSIS_DIR / "whisper-small.tsv"
WHISPER_MEDIUM = ANALYSIS_DIR / "whisper-medium.tsv"
WHISPER_LARGE_V1 = ANALYSIS_DIR / "whisper-large-v1.tsv"
WHISPER_LARGE_V2 = ANALYSIS_DIR / "whisper-large-v2.tsv"
WHISPER_LARGE_V3 = ANALYSIS_DIR / "whisper-large-v3.tsv"
FHNW = ANALYSIS_DIR / "fhnw.tsv"

# %% [markdown]
# ### Merge transcripts to compare

# %%
df_whisper_small = pd.read_csv(WHISPER_SMALL, sep="\t", encoding="utf-8-sig")
df_whisper_medium = pd.read_csv(WHISPER_MEDIUM, sep="\t", encoding="utf-8-sig")
df_whisper_large_v1 = pd.read_csv(WHISPER_LARGE_V1, sep="\t", encoding="utf-8-sig")
df_whisper_large_v2 = pd.read_csv(WHISPER_LARGE_V2, sep="\t", encoding="utf-8-sig")
df_whisper_large_v3 = pd.read_csv(WHISPER_LARGE_V3, sep="\t", encoding="utf-8-sig")
df_fhnw = pd.read_csv(FHNW, sep="\t", encoding="utf-8-sig")

frames = [
    df_fhnw[["path", "sentence", "transcript"]].rename(columns={"transcript": "transcript_fhnw"}),
    df_whisper_large_v1[["path", "transcript"]].rename(columns={"transcript": "transcript_v1"}),
    df_whisper_large_v2[["path", "transcript"]].rename(columns={"transcript": "transcript_v2"}),
    df_whisper_large_v3[["path", "transcript"]].rename(columns={"transcript": "transcript_v3"}),
    df_whisper_medium[["path", "transcript"]].rename(columns={"transcript": "transcript_medium"}),
    df_whisper_small[["path", "transcript"]].rename(columns={"transcript": "transcript_small"}),
]

df_transcripts = reduce(lambda left, right: pd.merge(left, right, on="path", how="inner"), frames)
df_transcripts.head()
# Out:
#                                                 path  \
# 0  datasets/STT4SG-350 v2.1/clips__train_valid-00...
# 1  datasets/STT4SG-350 v2.1/clips__train_valid-00...
# 2  datasets/STT4SG-350 v2.1/clips__train_valid-00...
# 3  datasets/STT4SG-350 v2.1/clips__train_valid-00...
# 4  datasets/STT4SG-350 v2.1/clips__train_valid-00...
#
#                                             sentence  \
# 0  Insgesamt habe ich einige Hunderttausend Frank...
# 1  Welche Rolle hatte Rosenberg während des Holoc...
# 2  Das ist angesichts aller schlechten Optionen d...
# 3  Ebenfalls keinen Sieg durfte die AC Milan feiern.
# 4  Viele Fussballfans haben die Alte Reithalle un...
#
#                                      transcript_fhnw  \
# 0  Insgesamt habe ich einige Hunderttausend Frank...
# 1  Welche Rolle hatte Rosenberg während des Holoc...
# 2  Das ist angesichts aller schlechten Optionen d...
# 3      Ebenfalls keinen Sieg durfte AC Milan feiern.
# 4  Viele Fussballfans haben die alte Reithalle un...
#
#                                        transcript_v1  \
# 0  Insgesamt habe ich einige Hunderttausend Frank...
# 1  Welche Rolle hätte Roseberg während des Holoca...
# 2  Das ist angesichts aller schlechter Optionen d...
# 3    Ebenfalls kein Sieg hat AC Milan feiern dürfen.
# 4  Viele Fussballfans haben die Alt-Rheintale unt...
#
#                                        transcript_v2  \
# 0  Insgesamt habe ich einige hunderttausend Frank...
# 1  Welche Rolle hatte Rausenberg während des Holo...
# 2  Das ist angesichts aller schlechten Optionen d...
# 3        Ebenfalls kein Sieg durfte AC Milan feiern.
# 4  Viele Fussballfans haben die Alt-Rheintaler un...
#
#                                        transcript_v3  \
# 0  Insgesamt habe ich einige hunderttausend Frank...
# 1  Welche Rolle hatte Rosenberg während dem Holoc...
# 2  Das ist angesichts aller schlechten Optionen d...
# 3        Ebenfalls kein Sieg durfte AC Milan feiern.
# 4  Viele Fussballfans haben die Altritalen unters...
#
#                                    transcript_medium  \
# 0  Insgesamt habe ich einige 100'000 Franken verl...
# 1  Welche Rolle hatte Rosenberg während des Holoc...
# 2  Das ist angesichts aller schlechten Optionen d...
# 3        Ebenfalls kein Sieg durfte AC Milan feiern.
# 4  Viele Fussballfans haben die Alt-Rheintaler un...
#
#                                     transcript_small
# 0  Insgesamt habe ich einige hunderttausend Frank...
# 1  Welche Rolle hätte ein Rosenberg während des H...
# 2  Das ist angesichts von allen schlechten Option...
# 3     Aber falls kein Sieg hat AC Milan dürfen vier.
# 4  Viele Fußballfans haben die Alldriehtale unter...

# %% [markdown]
# ## Learning
#
# - prompted is not what we want
# - wav2vec2 doesn't transcribe well enough
# - whisper-v2 still keeps dialect specific words, sometimes misinterprets them
#
# => DAT: FHNW, DIT: whisper-v2
